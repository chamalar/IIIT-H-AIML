# %% [markdown]
# <a href="https://colab.research.google.com/github/chamalar/IIIT-H-AIML/blob/master/Marvelchar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://marvel-thor.surge.sh/"
page = urlopen(url)

# %%
#soup = BeautifulSoup(page, 'html.parser')
soup = BeautifulSoup(page, 'lxml')
#print(soup)

# %%
name=[]
i=0
whole_data = soup.find_all('div', attrs={'class': "col-lg-8 mx-auto"})
#name_box = soup.find_all('h2')
#print(len(whole_data))
for eachiter in whole_data:
  x=eachiter.find_all('p',attrs={'class':'h2'})
  cleanx=BeautifulSoup(str(x), "lxml").get_text()
  cleanx=cleanx.strip('[]')
  #print(len(cleanx))
  if len(cleanx)==0:
    i=i+1
    x=eachiter.find_all('h2')
    cleanx=BeautifulSoup(str(x), "lxml").get_text()
    cleanx=cleanx.strip('[]')
    #print(i,cleanx)
    #print(i)
    #print(cleanx)
  name.append(cleanx)
  #print(name)

print(len(name))
print(name)
# Out:
# 2000
# ['robert washington (earth-616)', 'steve jackson (earth-616)', 'axonn-karr (earth-616)', 'menalaos (earth-616)', 'mia lessing (earth-616)', 'johnny dee (earth-616)', 'arsenal (robot) (earth-616)', 'esteban coraz\\u00f3n de ablo (earth-616)', 'yod (earth-616)', 'jason dean (earth-616)', 'jaketch (earth-616)', 'answer (hobgoblin) (earth-616)', 'skurge (earth-616)', 'br\\u00fcn (earth-616)', 'uatu (heroes reborn) (earth-616)', 'helio (earth-616)', 'grace (earth-616)', 'henry russo (earth-616)', 'valdor (earth-616)', 'priapus (earth-616)', 'host (pathogen) (earth-616)', 'carver (earth-616)', 'charon (olympian) (earth-616)', 'venkat katregadda (earth-616)', 'merlin (robot) (earth-616)', 'billy turner (earth-616)', 'sandy york (earth-616)', 'heiji shigematsu (earth-616)', 'frank craben (earth-616)', 'anna frankenstein (earth-616)', 'damon larsen (earth-616)', 'piskas (earth-616)', 'emory lewis (earth-616)', 'perun (earth-616)', 'carrie (earth-616)', 'prince rey (earth-616)', 'doris horton (earth-616)', 'eric prawn (earth-616)', 'caitlin maddox (earth-616)', 'doctor scarr (earth-616)', 'montgomery burns (earth-616)', 'ernesto sapristi (earth-616)', 'rachel sweet (earth-616)', 'mister x (earth-616)', 'siena blaze (earth-616)', 'firebrick (earth-616)', 'shagreen (earth-5311)', 'genkotsu (earth-616)', 'triax (new man) (earth-616)', 'njeri damphousse (earth-616)', 'vandal (earth-616)', 'arnold kaminsky (earth-616)', 'claude nite (earth-616)', 'kabar brashir (earth-616)', 'monkey (earth-616)', 'john sharpe (earth-616)', 'hosni (earth-616)', 'john horton (earth-616)', 'jamie jacobs (earth-616)', 'irham (earth-616)', 'urd (earth-616)', 'jay little bear (earth-616)', 'xennon (earth-616)', 'atalanta (argonauts) (earth-616)', 'linda donaldson (earth-616)', 'byron calley (earth-616)', 'dulb (earth-616)', 'dawn fury (earth-616)', 'benjamin savannah (earth-616)', 'william allen (earth-616)', 'bernie dillon (earth-616)', 'andreas de ruyter (earth-616)', 'bonegrinder (earth-616)', 'nokomis (earth-616)', 'sovel redhand (earth-616)', 'galin (earth-616)', 'rugga (earth-616)', 'victor borkowski (earth-616)', 'ivan kragoff (earth-616)', 'pete zamora (earth-616)', 'enigmo (earth-616)', 'baal (gabriel) (earth-616)', 'black curator (earth-616)', 'orville nugent (earth-616)', 'imus champion (earth-616)', 'aban (earth-616)', 'leonard samson (earth-616)', 'meryet karim (earth-616)', 'nails bradley (earth-616)', 'ellie phimister (earth-616)', 'sentinel x (earth-616)', 'smithy (earth-616)', 'pietro maximoff (earth-616)', 'keith roberts (earth-616)', 'rupert dockery (earth-616)', 'simone desantos (earth-982)', 'theodore marley brooks (earth-616)', 'charles, prince of wales (earth-616)', 'arthur maddicks (earth-616)', 'rafael scarfe (earth-616)', 'frank jenks (earth-616)', 'sentinel 6 (earth-616)', 'nemean lion (earth-616)', 'madame drache (earth-616)', 'peter (leopard girl ally) (earth-616)', 'ingesteev (earth-616)', 'white dragon (iron man) (earth-616)', 'lloyd bloch (heroes reborn) (earth-616)', 'li hua (earth-616)', 'contract (earth-616)', 'devron (earth-616)', 'virgo (lmd) (earth-616)', 'major cullen (earth-616)', 'mara (earth-616)', 'hecate (earth-616)', 'niomi brinke (earth-616)', 'kamal el alaoui (earth-616)', 'marcus baldry (earth-616)', 'adam peters (earth-616)', 'joy adams (earth-616)', 'thomas maximoff (earth-616)', 'malcolm knight (earth-616)', 'james david (earth-616)', 'aqwen (earth-616)', 'askare (earth-616)', 'doctor foster (earth-616)', 'gareth (spartoi) (earth-616)', 'malcolm murphy (earth-616)', 'ozel (earth-616)', 'michael stockton (earth-616)', 'yurthagg (earth-616)', 'dmitri smerdyakov (earth-616)', 'jason adamson (earth-616)', 'agnar of vanaheim (earth-616)', 'cholly (earth-616)', 'diomedes (earth-616)', 'saber (earth-616)', 'rex (earth-616)', 'teslav tarasova (earth-616)', 'william destine (earth-616)', 'matthew risman (earth-616)', 'tybalt (microverse) (earth-616)', 'ho yinsen (earth-616)', 'kru (earth-616)', 'horace littleton (earth-616 ...

# %%
name1_box = soup.find_all('p', attrs={'class': 'h4'})
for name in name1_box:
  print(name.text)
#print(name_box)

# %%
for link in soup.find_all('a'):
    if link.has_attr('href'):
        print(link.text)
