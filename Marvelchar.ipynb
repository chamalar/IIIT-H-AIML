# %% [markdown]
# <a href="https://colab.research.google.com/github/chamalar/IIIT-H-AIML/blob/master/Marvelchar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://marvel-thor.surge.sh/"
page = urlopen(url)

# %%
#soup = BeautifulSoup(page, 'html.parser')
soup = BeautifulSoup(page, 'lxml')
#print(soup)

# %%
name=[]
characterstics=[]
Identity=[] 
Align=[]
Eye=[]
Hair=[]
Sex=[]
Alive=[]
Appearances=[]
First_Appearance=[]
Year=[]
i=0
j=0
whole_data = soup.find_all('div', attrs={'class': "col-lg-8 mx-auto"})
#name_box = soup.find_all('h2')
#print(len(whole_data))
for eachiter in whole_data:
  j=j+1
  x=eachiter.find_all('p',attrs={'class':'h2'})
  cleanx=BeautifulSoup(str(x), "lxml").get_text()
  cleanx=cleanx.strip('[]')
  #print(len(cleanx))
  if len(cleanx)==0:
    i=i+1
    x=eachiter.find_all('h2')
    cleanx=BeautifulSoup(str(x), "lxml").get_text()
    cleanx=cleanx.strip('[]')
    #print(i,cleanx)
    #print(i)
    #print(cleanx)
  name.append(cleanx)
  #print(name)
  
  #y=eachiter.find_all('p',attrs={'class':'h4'})
  y=eachiter.find_all('a', href=True)
  cleany=BeautifulSoup(str(y), "lxml").get_text()
  cleany=cleany.strip('[]')
  cleany=cleany.split(',')
  characterstics.append(cleany)
  #if j==2:
  #  print(cleany)
  #print(y['href'])
  #if strip(cleany)="Identity":
  #  i=i+1
  #Identity.append(cleany)
  
#print(len(name))
#print(name)
print(type(characterstics))
print(len(characterstics))
# Out:
# <class 'list'>
# 2000

# %%
name1_box = soup.find_all('p', attrs={'class': 'h4'})
for name in name1_box:
  print(name.text)
#print(name_box)
# Out:
# Identity : None
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 32.0
# First Appearance : dec-79
# Year : 1979.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : feb-65
# Year : 1965.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : jun-42
# Year : 1942.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : dec-81
# Year : 1981.0
# Identity : public identity
# Align : bad characters
# Eye : blue eyes
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 12.0
# First Appearance : feb-06
# Year : 2006.0
# Identity : secret identity
# Align : bad characters
# Eye : red eyes
# Hair : no hair
# Sex : None
# Alive : living characters
# Appearances : 13.0
# First Appearance : sep-78
# Year : 1978.0
# Identity : secret identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 72.0
# First Appearance : sep-64
# Year : 1964.0
# Identity : None
# Align : neutral characters
# Eye : None
# Hair : no hair
# Sex : None
# Alive : living characters
# Appearances : 6.0
# First Appearance : feb-91
# Year : 1991.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : aug-77
# Year : 1977.0
# Identity : secret identity
# Align : bad characters
# Eye : green eyes
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : may-79
# Year : 1979.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : None
# Year : None
# Identity : secret identity
# Align : bad characters
# Eye : blue eyes
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 88.0
# First Appearance : apr-64
# Year : 1964.0
# Identity : secret identity
# Align : bad characters
# Eye : white eyes
# Hair : white hair
# Sex : female characters
# Alive : living characters
# Appearances : 16.0
# First Appearance : aug-10
# Year : 2010.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 5.0
# First Appearance : may-97
# Year : 1997.0
# Identity : secret identity
# Align : None
# Eye : brown eyes
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 8.0
# First Appearance : oct-07
# Year : 2007.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 28.0
# First Appearance : mar-09
# Year : 2009.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : red hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : jul-88
# Year : 1988.0
# Identity : None
# Align : bad characters
# Eye : yellow eyes
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 9.0
# First Appearance : apr-93
# Year : 1993.0
# Identity : None
# Align : None
# Eye : blue eyes
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 10.0
# First Appearance : dec-03
# Year : 2003.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : apr-93
# Year : 1993.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 8.0
# First Appearance : jan-82
# Year : 1982.0
# Identity : secret identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 8.0
# First Appearance : mar-99
# Year : 1999.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : None
# Sex : None
# Alive : living characters
# Appearances : 2.0
# First Appearance : mar-76
# Year : 1976.0
# Identity : secret identity
# Align : good characters
# Eye : blue eyes
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : oct-00
# Year : 2000.0
# Identity : no dual identity
# Align : good characters
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : oct-76
# Year : 1976.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : nov-84
# Year : 1984.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : sep-43
# Year : 1943.0
# Identity : no dual identity
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : jun-44
# Year : 1944.0
# Identity : public identity
# Align : neutral characters
# Eye : None
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : feb-73
# Year : 1973.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : apr-76
# Year : 1976.0
# Identity : secret identity
# Align : good characters
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 22.0
# First Appearance : apr-89
# Year : 1989.0
# Identity : secret identity
# Align : good characters
# Eye : green eyes
# Hair : grey hair
# Sex : female characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : oct-04
# Year : 2004.0
# Identity : no dual identity
# Align : bad characters
# Eye : blue eyes
# Hair : blond hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 12.0
# First Appearance : jul-66
# Year : 1966.0
# Identity : no dual identity
# Align : good characters
# Eye : None
# Hair : brown hair
# Sex : female characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : jan-43
# Year : 1943.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : jan-75
# Year : 1975.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : brown hair
# Sex : female characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : jun-94
# Year : 1994.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : dec-44
# Year : 1944.0
# Identity : no dual identity
# Align : None
# Eye : None
# Hair : bald
# Sex : male characters
# Alive : living characters
# Appearances : 21.0
# First Appearance : jul-97
# Year : 1997.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : nov-86
# Year : 1986.0
# Identity : None
# Align : bad characters
# Eye : blue eyes
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : jan-80
# Year : 1980.0
# Identity : secret identity
# Align : bad characters
# Eye : blue eyes
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 24.0
# First Appearance : feb-01
# Year : 2001.0
# Identity : public identity
# Align : bad characters
# Eye : brown eyes
# Hair : blond hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 29.0
# First Appearance : jan-93
# Year : 1993.0
# Identity : public identity
# Align : bad characters
# Eye : red eyes
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : nov-85
# Year : 1985.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : oct-93
# Year : 1993.0
# Identity : no dual identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 11.0
# First Appearance : dec-72
# Year : 1972.0
# Identity : secret identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : jun-05
# Year : 2005.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jul-94
# Year : 1994.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : may-87
# Year : 1987.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : dec-42
# Year : 1942.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : apr-06
# Year : 2006.0
# Identity : secret identity
# Align : None
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : nov-88
# Year : 1988.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 7.0
# First Appearance : dec-94
# Year : 1994.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : nov-90
# Year : 1990.0
# Identity : public identity
# Align : bad characters
# Eye : yellow eyes
# Hair : yellow hair
# Sex : male characters
# Alive : living characters
# Appearances : 74.0
# First Appearance : nov-72
# Year : 1972.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 3.0
# First Appearance : feb-67
# Year : 1967.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : grey hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : None
# Year : None
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 32.0
# First Appearance : jan-68
# Year : 1968.0
# Identity : None
# Align : None
# Eye : red eyes
# Hair : None
# Sex : None
# Alive : living characters
# Appearances : 2.0
# First Appearance : dec-05
# Year : 2005.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jul-08
# Year : 2008.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 9.0
# First Appearance : mar-72
# Year : 1972.0
# Identity : secret identity
# Align : bad characters
# Eye : blue eyes
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 19.0
# First Appearance : nov-77
# Year : 1977.0
# Identity : None
# Align : None
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : nov-82
# Year : 1982.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : aug-67
# Year : 1967.0
# Identity : no dual identity
# Align : None
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : sep-72
# Year : 1972.0
# Identity : secret identity
# Align : bad characters
# Eye : yellow eyes
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 13.0
# First Appearance : apr-97
# Year : 1997.0
# Identity : no dual identity
# Align : good characters
# Eye : None
# Hair : red hair
# Sex : male characters
# Alive : living characters
# Appearances : 31.0
# First Appearance : sep-76
# Year : 1976.0
# Identity : None
# Align : None
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 7.0
# First Appearance : dec-80
# Year : 1980.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : no hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 3.0
# First Appearance : oct-11
# Year : 2011.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jan-51
# Year : 1951.0
# Identity : public identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 13.0
# First Appearance : mar-09
# Year : 2009.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : mar-64
# Year : 1964.0
# Identity : secret identity
# Align : good characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 184.0
# First Appearance : aug-03
# Year : 2003.0
# Identity : secret identity
# Align : bad characters
# Eye : brown eyes
# Hair : grey hair
# Sex : male characters
# Alive : living characters
# Appearances : 71.0
# First Appearance : apr-63
# Year : 1963.0
# Identity : no dual identity
# Align : good characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : mar-90
# Year : 1990.0
# Identity : secret identity
# Align : None
# Eye : brown eyes
# Hair : red hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jan-94
# Year : 1994.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 6.0
# First Appearance : nov-98
# Year : 1998.0
# Identity : public identity
# Align : bad characters
# Eye : white eyes
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : aug-93
# Year : 1993.0
# Identity : None
# Align : None
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 4.0
# First Appearance : jul-93
# Year : 1993.0
# Identity : public identity
# Align : bad characters
# Eye : blue eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 14.0
# First Appearance : mar-73
# Year : 1973.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : jul-09
# Year : 2009.0
# Identity : public identity
# Align : good characters
# Eye : brown eyes
# Hair : green hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 260.0
# First Appearance : jul-71
# Year : 1971.0
# Identity : secret identity
# Align : neutral characters
# Eye : yellow eyes
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 19.0
# First Appearance : oct-90
# Year : 1990.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : sep-44
# Year : 1944.0
# Identity : secret identity
# Align : neutral characters
# Eye : black eyes
# Hair : black hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 14.0
# First Appearance : aug-01
# Year : 2001.0
# Identity : secret identity
# Align : bad characters
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 5.0
# First Appearance : may-12
# Year : 2012.0
# Identity : public identity
# Align : good characters
# Eye : blue eyes
# Hair : silver hair
# Sex : male characters
# Alive : living characters
# Appearances : 740.0
# First Appearance : mar-64
# Year : 1964.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : apr-93
# Year : 1993.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 8.0
# First Appearance : may-80
# Year : 1980.0
# Identity : secret identity
# Align : neutral characters
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 14.0
# First Appearance : jan-08
# Year : 2008.0
# Identity : no dual identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 17.0
# First Appearance : None
# Year : None
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : grey hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : None
# Year : None
# Identity : no dual identity
# Align : good characters
# Eye : white eyes
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 133.0
# First Appearance : mar-86
# Year : 1986.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 44.0
# First Appearance : aug-75
# Year : 1975.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jan-73
# Year : 1973.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : None
# Alive : living characters
# Appearances : 3.0
# First Appearance : nov-65
# Year : 1965.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jun-10
# Year : 2010.0
# Identity : secret identity
# Align : neutral characters
# Eye : None
# Hair : None
# Sex : female characters
# Alive : deceased characters
# Appearances : 2.0
# First Appearance : dec-01
# Year : 2001.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : oct-54
# Year : 1954.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 2.0
# First Appearance : jul-71
# Year : 1971.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : feb-02
# Year : 2002.0
# Identity : None
# Align : good characters
# Eye : brown eyes
# Hair : black hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 19.0
# First Appearance : oct-07
# Year : 2007.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : apr-93
# Year : 1993.0
# Identity : None
# Align : neutral characters
# Eye : None
# Hair : None
# Sex : None
# Alive : living characters
# Appearances : 2.0
# First Appearance : dec-05
# Year : 2005.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : strawberry blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 7.0
# First Appearance : aug-77
# Year : 1977.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : grey hair
# Sex : male characters
# Alive : living characters
# Appearances : 8.0
# First Appearance : mar-51
# Year : 1951.0
# Identity : public identity
# Align : good characters
# Eye : black eyes
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jul-94
# Year : 1994.0
# Identity : no dual identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 9.0
# First Appearance : nov-77
# Year : 1977.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : apr-97
# Year : 1997.0
# Identity : secret identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 8.0
# First Appearance : nov-96
# Year : 1996.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : nov-04
# Year : 2004.0
# Identity : no dual identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : jun-88
# Year : 1988.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : aug-90
# Year : 1990.0
# Identity : secret identity
# Align : bad characters
# Eye : blue eyes
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : jun-90
# Year : 1990.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : jun-93
# Year : 1993.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : nov-11
# Year : 2011.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : sep-78
# Year : 1978.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 4.0
# First Appearance : jan-06
# Year : 2006.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jun-77
# Year : 1977.0
# Identity : secret identity
# Align : neutral characters
# Eye : green eyes
# Hair : orange hair
# Sex : male characters
# Alive : living characters
# Appearances : 18.0
# First Appearance : jan-93
# Year : 1993.0
# Identity : no dual identity
# Align : neutral characters
# Eye : green eyes
# Hair : green hair
# Sex : female characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : may-84
# Year : 1984.0
# Identity : secret identity
# Align : bad characters
# Eye : blue eyes
# Hair : bald
# Sex : male characters
# Alive : living characters
# Appearances : 16.0
# First Appearance : jul-72
# Year : 1972.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : jan-86
# Year : 1986.0
# Identity : secret identity
# Align : bad characters
# Eye : variable eyes
# Hair : variable hair
# Sex : male characters
# Alive : living characters
# Appearances : 146.0
# First Appearance : mar-63
# Year : 1963.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : jun-74
# Year : 1974.0
# Identity : secret identity
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 18.0
# First Appearance : dec-83
# Year : 1983.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : apr-87
# Year : 1987.0
# Identity : secret identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : apr-12
# Year : 2012.0
# Identity : secret identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 5.0
# First Appearance : aug-95
# Year : 1995.0
# Identity : None
# Align : neutral characters
# Eye : blue eyes
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : mar-13
# Year : 2013.0
# Identity : secret identity
# Align : None
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 9.0
# First Appearance : feb-95
# Year : 1995.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 16.0
# First Appearance : mar-06
# Year : 2006.0
# Identity : no dual identity
# Align : neutral characters
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : jun-81
# Year : 1981.0
# Identity : public identity
# Align : good characters
# Eye : brown eyes
# Hair : white hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 32.0
# First Appearance : mar-63
# Year : 1963.0
# Identity : no dual identity
# Align : neutral characters
# Eye : None
# Hair : None
# Sex : None
# Alive : living characters
# Appearances : 2.0
# First Appearance : oct-39
# Year : 1939.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : None
# Year : None
# Identity : no dual identity
# Align : good characters
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : apr-40
# Year : 1940.0
# Identity : no dual identity
# Align : good characters
# Eye : brown eyes
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 128.0
# First Appearance : jan-68
# Year : 1968.0
# Identity : no dual identity
# Align : None
# Eye : blue eyes
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : jan-93
# Year : 1993.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : mar-45
# Year : 1945.0
# Identity : public identity
# Align : good characters
# Eye : grey eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 33.0
# First Appearance : jun-77
# Year : 1977.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : bald
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : dec-81
# Year : 1981.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : jul-51
# Year : 1951.0
# Identity : secret identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : dec-89
# Year : 1989.0
# Identity : no dual identity
# Align : neutral characters
# Eye : green eyes
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 8.0
# First Appearance : dec-03
# Year : 2003.0
# Identity : secret identity
# Align : bad characters
# Eye : blue eyes
# Hair : blond hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 2.0
# First Appearance : aug-06
# Year : 2006.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : bald
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : may-98
# Year : 1998.0
# Identity : secret identity
# Align : bad characters
# Eye : green eyes
# Hair : red hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 3.0
# First Appearance : oct-98
# Year : 1998.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : oct-74
# Year : 1974.0
# Identity : public identity
# Align : neutral characters
# Eye : blue eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : nov-74
# Year : 1974.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 2.0
# First Appearance : dec-92
# Year : 1992.0
# Identity : secret identity
# Align : bad characters
# Eye : red eyes
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : feb-94
# Year : 1994.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : oct-42
# Year : 1942.0
# Identity : secret identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : dec-82
# Year : 1982.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : dec-94
# Year : 1994.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 6.0
# First Appearance : apr-81
# Year : 1981.0
# Identity : None
# Align : None
# Eye : blue eyes
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 72.0
# First Appearance : nov-85
# Year : 1985.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : apr-03
# Year : 2003.0
# Identity : public identity
# Align : neutral characters
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : sep-48
# Year : 1948.0
# Identity : public identity
# Align : good characters
# Eye : blue eyes
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : dec-81
# Year : 1981.0
# Identity : None
# Align : neutral characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : sep-10
# Year : 2010.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : jan-81
# Year : 1981.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : red hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : sep-41
# Year : 1941.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 2.0
# First Appearance : may-11
# Year : 2011.0
# Identity : None
# Align : bad characters
# Eye : blue eyes
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : oct-91
# Year : 1991.0
# Identity : secret identity
# Align : neutral characters
# Eye : green eyes
# Hair : red hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 38.0
# First Appearance : jun-84
# Year : 1984.0
# Identity : secret identity
# Align : good characters
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 22.0
# First Appearance : aug-91
# Year : 1991.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 11.0
# First Appearance : jan-73
# Year : 1973.0
# Identity : no dual identity
# Align : good characters
# Eye : None
# Hair : brown hair
# Sex : female characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : dec-39
# Year : 1939.0
# Identity : secret identity
# Align : None
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : aug-67
# Year : 1967.0
# Identity : no dual identity
# Align : good characters
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 166.0
# First Appearance : sep-63
# Year : 1963.0
# Identity : secret identity
# Align : good characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : aug-78
# Year : 1978.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : apr-05
# Year : 2005.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : mar-40
# Year : 1940.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 12.0
# First Appearance : jul-92
# Year : 1992.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : sep-43
# Year : 1943.0
# Identity : public identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 57.0
# First Appearance : mar-64
# Year : 1964.0
# Identity : None
# Align : bad characters
# Eye : red eyes
# Hair : bald
# Sex : male characters
# Alive : living characters
# Appearances : 11.0
# First Appearance : feb-07
# Year : 2007.0
# Identity : public identity
# Align : neutral characters
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 35.0
# First Appearance : mar-83
# Year : 1983.0
# Identity : secret identity
# Align : good characters
# Eye : green eyes
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 18.0
# First Appearance : sep-04
# Year : 2004.0
# Identity : secret identity
# Align : good characters
# Eye : None
# Hair : bald
# Sex : male characters
# Alive : deceased characters
# Appearances : 2.0
# First Appearance : apr-07
# Year : 2007.0
# Identity : public identity
# Align : neutral characters
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : mar-43
# Year : 1943.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : dec-41
# Year : 1941.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : jul-45
# Year : 1945.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : sep-88
# Year : 1988.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : no hair
# Sex : None
# Alive : living characters
# Appearances : 31.0
# First Appearance : feb-40
# Year : 1940.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : mar-70
# Year : 1970.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : apr-55
# Year : 1955.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : bald
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : oct-12
# Year : 2012.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : brown hair
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : may-42
# Year : 1942.0
# Identity : None
# Align : neutral characters
# Eye : None
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : oct-63
# Year : 1963.0
# Identity : secret identity
# Align : good characters
# Eye : None
# Hair : brown hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 15.0
# First Appearance : oct-97
# Year : 1997.0
# Identity : no dual identity
# Align : neutral characters
# Eye : brown eyes
# Hair : brown hair
# Sex : female characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : None
# Year : None
# Identity : public identity
# Align : None
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : jan-78
# Year : 1978.0
# Identity : secret identity
# Align : neutral characters
# Eye : None
# Hair : bald
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : jul-04
# Year : 2004.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : dec-74
# Year : 1974.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : apr-44
# Year : 1944.0
# Identity : secret identity
# Align : neutral characters
# Eye : blue eyes
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : nov-11
# Year : 2011.0
# Identity : no dual identity
# Align : good characters
# Eye : brown eyes
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 325.0
# First Appearance : apr-05
# Year : 2005.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : aug-42
# Year : 1942.0
# Identity : public identity
# Align : bad characters
# Eye : blue eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : mar-63
# Year : 1963.0
# Identity : secret identity
# Align : good characters
# Eye : gold eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : dec-96
# Year : 1996.0
# Identity : no dual identity
# Align : neutral characters
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : aug-87
# Year : 1987.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : None
# Sex : None
# Alive : living characters
# Appearances : 3.0
# First Appearance : mar-76
# Year : 1976.0
# Identity : public identity
# Align : None
# Eye : black eyes
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : dec-87
# Year : 1987.0
# Identity : secret identity
# Align : neutral characters
# Eye : None
# Hair : no hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 3.0
# First Appearance : nov-08
# Year : 2008.0
# Identity : public identity
# Align : good characters
# Eye : blue eyes
# Hair : red hair
# Sex : female characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : dec-93
# Year : 1993.0
# Identity : no dual identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 8.0
# First Appearance : apr-64
# Year : 1964.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : apr-88
# Year : 1988.0
# Identity : public identity
# Align : good characters
# Eye : red eyes
# Hair : grey hair
# Sex : male characters
# Alive : living characters
# Appearances : 686.0
# First Appearance : oct-64
# Year : 1964.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : sep-02
# Year : 2002.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : oct-97
# Year : 1997.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : feb-76
# Year : 1976.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : may-11
# Year : 2011.0
# Identity : secret identity
# Align : bad characters
# Eye : white eyes
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 33.0
# First Appearance : oct-77
# Year : 1977.0
# Identity : public identity
# Align : good characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 49.0
# First Appearance : sep-40
# Year : 1940.0
# Identity : no dual identity
# Align : good characters
# Eye : None
# Hair : grey hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 2.0
# First Appearance : mar-92
# Year : 1992.0
# Identity : None
# Align : None
# Eye : brown eyes
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 8.0
# First Appearance : jun-05
# Year : 2005.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : jun-71
# Year : 1971.0
# Identity : no dual identity
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : feb-42
# Year : 1942.0
# Identity : public identity
# Align : bad characters
# Eye : blue eyes
# Hair : bald
# Sex : male characters
# Alive : deceased characters
# Appearances : 73.0
# First Appearance : jun-65
# Year : 1965.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : red hair
# Sex : male characters
# Alive : living characters
# Appearances : 10.0
# First Appearance : mar-71
# Year : 1971.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : dec-64
# Year : 1964.0
# Identity : secret identity
# Align : None
# Eye : white eyes
# Hair : green hair
# Sex : female characters
# Alive : living characters
# Appearances : 9.0
# First Appearance : aug-04
# Year : 2004.0
# Identity : secret identity
# Align : bad characters
# Eye : yellow eyes
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 14.0
# First Appearance : feb-70
# Year : 1970.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : sep-55
# Year : 1955.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : sep-42
# Year : 1942.0
# Identity : secret identity
# Align : good characters
# Eye : None
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : jan-04
# Year : 2004.0
# Identity : secret identity
# Align : neutral characters
# Eye : brown eyes
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : mar-93
# Year : 1993.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 5.0
# First Appearance : nov-80
# Year : 1980.0
# Identity : secret identity
# Align : neutral characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : dec-60
# Year : 1960.0
# Identity : no dual identity
# Align : bad characters
# Eye : None
# Hair : bald
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : jul-93
# Year : 1993.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : None
# Sex : None
# Alive : living characters
# Appearances : 1.0
# First Appearance : may-40
# Year : 1940.0
# Identity : no dual identity
# Align : bad characters
# Eye : None
# Hair : green hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : apr-87
# Year : 1987.0
# Identity : no dual identity
# Align : neutral characters
# Eye : yellow eyes
# Hair : green hair
# Sex : female characters
# Alive : living characters
# Appearances : 23.0
# First Appearance : nov-08
# Year : 2008.0
# Identity : public identity
# Align : neutral characters
# Eye : None
# Hair : auburn hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jul-02
# Year : 2002.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 3.0
# First Appearance : mar-71
# Year : 1971.0
# Identity : secret identity
# Align : good characters
# Eye : yellow eyes
# Hair : red hair
# Sex : male characters
# Alive : living characters
# Appearances : 15.0
# First Appearance : mar-94
# Year : 1994.0
# Identity : secret identity
# Align : good characters
# Eye : brown eyes
# Hair : black hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 12.0
# First Appearance : mar-78
# Year : 1978.0
# Identity : secret identity
# Align : bad characters
# Eye : red eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 155.0
# First Appearance : sep-87
# Year : 1987.0
# Identity : no dual identity
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 4.0
# First Appearance : aug-76
# Year : 1976.0
# Identity : secret identity
# Align : bad characters
# Eye : red eyes
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 10.0
# First Appearance : feb-74
# Year : 1974.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : apr-11
# Year : 2011.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : aug-90
# Year : 1990.0
# Identity : None
# Align : bad characters
# Eye : yellow eyes
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 11.0
# First Appearance : may-83
# Year : 1983.0
# Identity : None
# Align : bad characters
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 7.0
# First Appearance : feb-86
# Year : 1986.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : may-91
# Year : 1991.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : feb-43
# Year : 1943.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : jul-66
# Year : 1966.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : feb-89
# Year : 1989.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : female characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : may-94
# Year : 1994.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : aug-99
# Year : 1999.0
# Identity : None
# Align : neutral characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : dec-97
# Year : 1997.0
# Identity : secret identity
# Align : None
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : nov-82
# Year : 1982.0
# Identity : no dual identity
# Align : None
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 36.0
# First Appearance : oct-75
# Year : 1975.0
# Identity : public identity
# Align : neutral characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : jul-05
# Year : 2005.0
# Identity : public identity
# Align : neutral characters
# Eye : yellow eyes
# Hair : no hair
# Sex : female characters
# Alive : living characters
# Appearances : 39.0
# First Appearance : may-07
# Year : 2007.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : no hair
# Sex : None
# Alive : deceased characters
# Appearances : 4.0
# First Appearance : apr-69
# Year : 1969.0
# Identity : secret identity
# Align : bad characters
# Eye : blue eyes
# Hair : blue hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 2.0
# First Appearance : dec-93
# Year : 1993.0
# Identity : None
# Align : neutral characters
# Eye : None
# Hair : None
# Sex : None
# Alive : living characters
# Appearances : 2.0
# First Appearance : jul-81
# Year : 1981.0
# Identity : public identity
# Align : bad characters
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : oct-72
# Year : 1972.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : may-55
# Year : 1955.0
# Identity : public identity
# Align : bad characters
# Eye : grey eyes
# Hair : no hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 68.0
# First Appearance : oct-79
# Year : 1979.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# ...
# Sex : female characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : jun-02
# Year : 2002.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : oct-92
# Year : 1992.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : mar-99
# Year : 1999.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : grey hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 3.0
# First Appearance : jun-72
# Year : 1972.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 43.0
# First Appearance : apr-79
# Year : 1979.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : grey hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : aug-75
# Year : 1975.0
# Identity : None
# Align : neutral characters
# Eye : black eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 7.0
# First Appearance : feb-76
# Year : 1976.0
# Identity : public identity
# Align : good characters
# Eye : green eyes
# Hair : red hair
# Sex : female characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : mar-78
# Year : 1978.0
# Identity : no dual identity
# Align : None
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 9.0
# First Appearance : dec-72
# Year : 1972.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : oct-78
# Year : 1978.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 26.0
# First Appearance : may-64
# Year : 1964.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : grey hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jun-88
# Year : 1988.0
# Identity : no dual identity
# Align : None
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 46.0
# First Appearance : jun-76
# Year : 1976.0
# Identity : None
# Align : None
# Eye : brown eyes
# Hair : brown hair
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : may-63
# Year : 1963.0
# Identity : secret identity
# Align : bad characters
# Eye : red eyes
# Hair : grey hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : mar-93
# Year : 1993.0
# Identity : secret identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 9.0
# First Appearance : apr-94
# Year : 1994.0
# Identity : secret identity
# Align : None
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : mar-94
# Year : 1994.0
# Identity : secret identity
# Align : good characters
# Eye : green eyes
# Hair : red hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 5.0
# First Appearance : dec-88
# Year : 1988.0
# Identity : secret identity
# Align : good characters
# Eye : blue eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 66.0
# First Appearance : feb-92
# Year : 1992.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : bald
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : jun-45
# Year : 1945.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : jun-46
# Year : 1946.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 10.0
# First Appearance : aug-12
# Year : 2012.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : apr-44
# Year : 1944.0
# Identity : secret identity
# Align : bad characters
# Eye : red eyes
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 30.0
# First Appearance : oct-75
# Year : 1975.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : jul-76
# Year : 1976.0
# Identity : public identity
# Align : neutral characters
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 7.0
# First Appearance : oct-05
# Year : 2005.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : None
# Alive : living characters
# Appearances : 1.0
# First Appearance : sep-42
# Year : 1942.0
# Identity : public identity
# Align : bad characters
# Eye : brown eyes
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 7.0
# First Appearance : aug-11
# Year : 2011.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : apr-80
# Year : 1980.0
# Identity : secret identity
# Align : bad characters
# Eye : brown eyes
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 5.0
# First Appearance : mar-99
# Year : 1999.0
# Identity : secret identity
# Align : neutral characters
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : dec-85
# Year : 1985.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 7.0
# First Appearance : None
# Year : None
# Identity : secret identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : female characters
# Alive : deceased characters
# Appearances : 10.0
# First Appearance : aug-77
# Year : 1977.0
# Identity : no dual identity
# Align : good characters
# Eye : blue eyes
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : mar-96
# Year : 1996.0
# Identity : None
# Align : bad characters
# Eye : black eyes
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 2.0
# First Appearance : may-03
# Year : 2003.0
# Identity : secret identity
# Align : bad characters
# Eye : blue eyes
# Hair : black hair
# Sex : female characters
# Alive : deceased characters
# Appearances : 19.0
# First Appearance : oct-08
# Year : 2008.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : feb-70
# Year : 1970.0
# Identity : no dual identity
# Align : None
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 4.0
# First Appearance : jan-68
# Year : 1968.0
# Identity : no dual identity
# Align : bad characters
# Eye : blue eyes
# Hair : red hair
# Sex : female characters
# Alive : living characters
# Appearances : 48.0
# First Appearance : nov-83
# Year : 1983.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : jun-89
# Year : 1989.0
# Identity : None
# Align : None
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : oct-93
# Year : 1993.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jun-95
# Year : 1995.0
# Identity : secret identity
# Align : bad characters
# Eye : red eyes
# Hair : bald
# Sex : male characters
# Alive : deceased characters
# Appearances : 4.0
# First Appearance : jan-94
# Year : 1994.0
# Identity : None
# Align : bad characters
# Eye : red eyes
# Hair : red hair
# Sex : male characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : aug-79
# Year : 1979.0
# Identity : no dual identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 4.0
# First Appearance : dec-68
# Year : 1968.0
# Identity : secret identity
# Align : None
# Eye : None
# Hair : red hair
# Sex : female characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : apr-77
# Year : 1977.0
# Identity : None
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : oct-02
# Year : 2002.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : sep-84
# Year : 1984.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : oct-43
# Year : 1943.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : mar-41
# Year : 1941.0
# Identity : None
# Align : neutral characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 8.0
# First Appearance : jul-97
# Year : 1997.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : mar-09
# Year : 2009.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : dec-94
# Year : 1994.0
# Identity : no dual identity
# Align : good characters
# Eye : variable eyes
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 113.0
# First Appearance : jul-01
# Year : 2001.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : grey hair
# Sex : female characters
# Alive : living characters
# Appearances : 7.0
# First Appearance : mar-49
# Year : 1949.0
# Identity : public identity
# Align : good characters
# Eye : pink eyes
# Hair : bald
# Sex : None
# Alive : living characters
# Appearances : 21.0
# First Appearance : mar-13
# Year : 2013.0
# Identity : public identity
# Align : good characters
# Eye : green eyes
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : oct-93
# Year : 1993.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : dec-79
# Year : 1979.0
# Identity : secret identity
# Align : neutral characters
# Eye : None
# Hair : blond hair
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jul-93
# Year : 1993.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 10.0
# First Appearance : jun-95
# Year : 1995.0
# Identity : public identity
# Align : good characters
# Eye : green eyes
# Hair : red hair
# Sex : female characters
# Alive : living characters
# Appearances : 12.0
# First Appearance : jun-84
# Year : 1984.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : may-80
# Year : 1980.0
# Identity : secret identity
# Align : neutral characters
# Eye : brown eyes
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 3.0
# First Appearance : None
# Year : None
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : living characters
# Appearances : 51.0
# First Appearance : aug-77
# Year : 1977.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : grey hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : sep-43
# Year : 1943.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : black hair
# Sex : female characters
# Alive : living characters
# Appearances : 4.0
# First Appearance : sep-98
# Year : 1998.0
# Identity : no dual identity
# Align : bad characters
# Eye : yellow eyes
# Hair : no hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 45.0
# First Appearance : apr-06
# Year : 2006.0
# Identity : public identity
# Align : neutral characters
# Eye : None
# Hair : bald
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : dec-48
# Year : 1948.0
# Identity : secret identity
# Align : good characters
# Eye : blue eyes
# Hair : white hair
# Sex : female characters
# Alive : living characters
# Appearances : 106.0
# First Appearance : may-63
# Year : 1963.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : aug-88
# Year : 1988.0
# Identity : public identity
# Align : bad characters
# Eye : None
# Hair : brown hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 1.0
# First Appearance : jun-50
# Year : 1950.0
# Identity : secret identity
# Align : bad characters
# Eye : blue eyes
# Hair : white hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 15.0
# First Appearance : jan-70
# Year : 1970.0
# Identity : None
# Align : bad characters
# Eye : blue eyes
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 5.0
# First Appearance : jul-01
# Year : 2001.0
# Identity : public identity
# Align : good characters
# Eye : None
# Hair : red hair
# Sex : female characters
# Alive : living characters
# Appearances : 19.0
# First Appearance : jun-02
# Year : 2002.0
# Identity : secret identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 43.0
# First Appearance : jan-72
# Year : 1972.0
# Identity : None
# Align : neutral characters
# Eye : None
# Hair : brown hair
# Sex : female characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : jul-88
# Year : 1988.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : black hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : may-61
# Year : 1961.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : feb-85
# Year : 1985.0
# Identity : secret identity
# Align : good characters
# Eye : None
# Hair : None
# Sex : female characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : aug-01
# Year : 2001.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : deceased characters
# Appearances : 2.0
# First Appearance : jun-74
# Year : 1974.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : None
# Alive : living characters
# Appearances : 1.0
# First Appearance : aug-90
# Year : 1990.0
# Identity : secret identity
# Align : bad characters
# Eye : green eyes
# Hair : black hair
# Sex : male characters
# Alive : deceased characters
# Appearances : 82.0
# First Appearance : dec-73
# Year : 1973.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : no hair
# Sex : male characters
# Alive : living characters
# Appearances : 3.0
# First Appearance : dec-85
# Year : 1985.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 2.0
# First Appearance : jul-72
# Year : 1972.0
# Identity : public identity
# Align : None
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 6.0
# First Appearance : feb-87
# Year : 1987.0
# Identity : None
# Align : None
# Eye : None
# Hair : None
# Sex : None
# Alive : living characters
# Appearances : 4.0
# First Appearance : jul-90
# Year : 1990.0
# Identity : None
# Align : None
# Eye : None
# Hair : blond hair
# Sex : female characters
# Alive : living characters
# Appearances : 7.0
# First Appearance : feb-83
# Year : 1983.0
# Identity : secret identity
# Align : bad characters
# Eye : None
# Hair : white hair
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : jan-87
# Year : 1987.0
# Identity : None
# Align : bad characters
# Eye : None
# Hair : None
# Sex : male characters
# Alive : living characters
# Appearances : 1.0
# First Appearance : apr-82
# Year : 1982.0

# %%
for link in soup.find_all('a'):
    if link.has_attr('href'):
        print(link.text)
